# %% [markdown]
# payrool

# %%
import pandas as pd

# %%
import numpy as np

# %%
data=pd.read_csv("C:/Users/enaam/OneDrive/Desktop/PYTHON/Payroll_Data.csv")

# %%
data
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 0                     F           Salary            NaN       107790.0
# ...

# %%
data.head()
# Out:
#                Name      Job Titles Department Full or Part-Time  \
# 0  ALLISON,  PAUL W      LIEUTENANT       FIRE                 F
# 1   BRUNO,  KEVIN D        SERGEANT     POLICE                 F
# 2   COOPER,  JOHN E  LIEUTENANT-EMT       FIRE                 F
# 3  CRESPO,  VILMA I      STAFF ASST        LAW                 F
# 4  DOLAN,  ROBERT J        SERGEANT     POLICE                 F
#
#   Salary or Hourly  Typical Hours  Annual Salary Hourly Rate
# 0           Salary            NaN       107790.0         NaN
# 1           Salary            NaN       104628.0         NaN
# 2           Salary            NaN       114324.0         NaN
# 3           Salary            NaN        76932.0         NaN
# 4           Salary            NaN       111474.0         NaN

# %% [markdown]
# 2-get overview of the data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32658 entries, 0 to 32657
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               32658 non-null  object
#  1   Job Titles         32658 non-null  object
#  2   Department         32658 non-null  object
#  3   Full or Part-Time  32658 non-null  object
#  4   Salary or Hourly   32658 non-null  object
#  5   Typical Hours      7883 non-null   float64
#  6   Annual Salary      24775 non-null  float64
#  7   Hourly Rate        7883 non-null   object
# dtypes: float64(2), object(6)
# memory usage: 2.0+ MB

# %% [markdown]
# 3-how many Nan in each coulmns

# %%
data.isnull().sum()
# Out:
# Name                     0
# Job Titles               0
# Department               0
# Full or Part-Time        0
# Salary or Hourly         0
# Typical Hours        24775
# Annual Salary         7883
# Hourly Rate          24775
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32658 entries, 0 to 32657
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               32658 non-null  object
#  1   Job Titles         32658 non-null  object
#  2   Department         32658 non-null  object
#  3   Full or Part-Time  32658 non-null  object
#  4   Salary or Hourly   32658 non-null  object
#  5   Typical Hours      7883 non-null   float64
#  6   Annual Salary      24775 non-null  float64
#  7   Hourly Rate        7883 non-null   object
# dtypes: float64(2), object(6)
# memory usage: 2.0+ MB

# %% [markdown]
# 4-statistic for the data

# %%
data.describe()
# Out:
#        Typical Hours  Annual Salary
# count    7883.000000   24775.000000
# mean       34.698719   87512.780149
# std         9.145553   20563.723220
# min        10.000000       1.000000
# 25%        20.000000   76932.000000
# 50%        40.000000   90024.000000
# 75%        40.000000   97368.000000
# max        40.000000  300000.000000

# %%
data.dtypes
# Out:
# Name                  object
# Job Titles            object
# Department            object
# Full or Part-Time     object
# Salary or Hourly      object
# Typical Hours        float64
# Annual Salary        float64
# Hourly Rate           object
# dtype: object

# %%
data.describe(include='all')
# Out:
#                       Name      Job Titles Department Full or Part-Time  \
# count                32658           32658      32658             32658
# unique               32350            1095         36                 2
# top     HERNANDEZ,  JUAN C  POLICE OFFICER     POLICE                 F
# freq                     5            9393      12973             30676
# mean                   NaN             NaN        NaN               NaN
# std                    NaN             NaN        NaN               NaN
# min                    NaN             NaN        NaN               NaN
# 25%                    NaN             NaN        NaN               NaN
# 50%                    NaN             NaN        NaN               NaN
# 75%                    NaN             NaN        NaN               NaN
# max                    NaN             NaN        NaN               NaN
#
#        Salary or Hourly  Typical Hours  Annual Salary Hourly Rate
# ...

# %% [markdown]
# 5-how to get statistic information for spesific coulmn

# %%
data['Typical Hours'].max()
# Out:
# 40.0

# %%
data['Typical Hours'].min()
# Out:
# 10.0

# %%
data['Typical Hours'].agg([max,min])
# Out:
# C:\Users\enaam\AppData\Local\Temp\ipykernel_14772\1007953656.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data['Typical Hours'].agg([max,min])
# C:\Users\enaam\AppData\Local\Temp\ipykernel_14772\1007953656.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data['Typical Hours'].agg([max,min])
# max    40.0
# min    10.0
# Name: Typical Hours, dtype: float64

# %%
print ("the maxumm value for Typical Hours is:",data['Typical Hours'].max())
# Out:
# the maxumm value for Typical Hours is: 40.0

# %%
print ("the maxumm value for Typical Hours is:",data['Typical Hours'].min())
# Out:
# the maxumm value for Typical Hours is: 10.0

# %%
print ("the maxumm value for Typical Hours is:",data['Typical Hours'].mean())
# Out:
# the maxumm value for Typical Hours is: 34.69871876189268

# %% [markdown]
# 5-how many employees are work on salary and hourly

# %%
data['Salary or Hourly'].value_counts()
# Out:
# Salary or Hourly
# Salary    24775
# Hourly     7883
# Name: count, dtype: int64

# %%
data['Salary or Hourly'].value_counts()
# Out:
# Salary or Hourly
# Salary    24775
# Hourly     7883
# Name: count, dtype: int64

# %%
data.groupby(['Salary or Hourly']).count()
# Out:
#                    Name  Job Titles  Department  Full or Part-Time  \
# Salary or Hourly
# Hourly             7883        7883        7883               7883
# Salary            24775       24775       24775              24775
#
#                   Typical Hours  Annual Salary  Hourly Rate
# Salary or Hourly
# Hourly                     7883              0         7883
# Salary                        0          24775            0

# %% [markdown]
# 6-which department has maxiunm of employee?

# %%
data['Department'].value_counts()
# Out:
# Department
# POLICE                   12973
# FIRE                      4800
# STREETS & SAN             2194
# OEMC                      2044
# WATER MGMNT               1878
# AVIATION                  1612
# TRANSPORTN                1103
# GENERAL SERVICES           972
# PUBLIC LIBRARY             932
# FAMILY & SUPPORT           621
# FINANCE                    575
# HEALTH                     516
# LAW                        405
# CITY COUNCIL               400
# BUILDINGS                  266
# COMMUNITY DEVELOPMENT      214
# BUSINESS AFFAIRS           168
# BOARD OF ELECTION          112
# DoIT                       101
# PROCUREMENT                 86
# MAYOR'S OFFICE              85
# CITY CLERK                  85
# CULTURAL AFFAIRS            76
# ANIMAL CONTRL               73
# HUMAN RESOURCES             68
# INSPECTOR GEN               63
# IPRA                        56
# BUDGET & MGMT               44
# ADMIN HEARNG                38
# ...

# %% [markdown]
# 7-how many employee in  the police department are salary and hourly?

# %%
data[data['Department']=='POLICE'].groupby('Salary or Hourly').count()['Department']
# Out:
# Salary or Hourly
# Hourly       32
# Salary    12941
# Name: Department, dtype: int64

# %% [markdown]
# 8- what is the max and min for salaries

# %%
data.dtypes
# Out:
# Name                  object
# Job Titles            object
# Department            object
# Full or Part-Time     object
# Salary or Hourly      object
# Typical Hours        float64
# Annual Salary        float64
# Hourly Rate           object
# dtype: object

# %%
data.drop('salary',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 data.drop('salary',axis=1,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
data['salary']=data['Annual Salary'].str.replace('$','').astype(float)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 data['salary']=data['Annual Salary'].str.replace('$','').astype(float)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\accessor.py:224, in CachedAccessor.__get__(self, obj, cls)
#     221 if obj is None:
#     222     # we're accessing the attribute of the class, i.e., Dataset.geo
#     223     return self._accessor
# --> 224 accessor_obj = self._accessor(obj)
# ...

# %%
data
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 0                     F           Salary            NaN       107790.0
# ...

# %%
 data['salary']=data['Annual Salary'].replace('$','')

# %%
data
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours  Annual Salary  \
# 0                     F           Salary            NaN       107790.0
# ...

# %%
data.dtypes
# Out:
# Name                  object
# Job Titles            object
# Department            object
# Full or Part-Time     object
# Salary or Hourly      object
# Typical Hours        float64
# Annual Salary        float64
# Hourly Rate           object
# salary               float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32658 entries, 0 to 32657
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               32658 non-null  object
#  1   Job Titles         32658 non-null  object
#  2   Department         32658 non-null  object
#  3   Full or Part-Time  32658 non-null  object
#  4   Salary or Hourly   32658 non-null  object
#  5   Typical Hours      7883 non-null   float64
#  6   Annual Salary      24775 non-null  float64
#  7   Hourly Rate        7883 non-null   object
#  8   salary             24775 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 2.2+ MB

# %%
data.drop('Annual Salary',axis=1,inplace=True)

# %%
data
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Hourly Rate    salary
# 0                     F           Salary            NaN         NaN  107790.0
# ...

# %%
data['salary'].agg([min,max])
# Out:
# C:\Users\enaam\AppData\Local\Temp\ipykernel_14772\1831832336.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data['salary'].agg([min,max])
# C:\Users\enaam\AppData\Local\Temp\ipykernel_14772\1831832336.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data['salary'].agg([min,max])
# min         1.0
# max    300000.0
# Name: salary, dtype: float64

# %% [markdown]
# 8-find an employy who has  maxumn salary?

# %%
data.drop(300000.0,axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 data.drop(300000.0,axis=1,inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# ...

# %%
data[data['salary']== data['salary'].max()]
# Out:
#                   Name                Job Titles Department Full or Part-Time  \
# 8310  EVANS,  GINGER S  COMMISSIONER OF AVIATION   AVIATION                 F
#
#      Salary or Hourly  Typical Hours Hourly Rate    salary
# 8310           Salary            NaN         NaN  300000.0

# %%
data.dtypes
# Out:
# Name                  object
# Job Titles            object
# Department            object
# Full or Part-Time     object
# Salary or Hourly      object
# Typical Hours        float64
# Hourly Rate           object
# salary               float64
# dtype: object

# %%
data
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Hourly Rate    salary
# 0                     F           Salary            NaN         NaN  107790.0
# ...

# %%
data[data['salary']== data['salary'].min()]
# Out:
#                  Name                Job Titles      Department  \
# 15387  KOCH,  STEVEN   ADMINISTRATIVE SECRETARY  MAYOR'S OFFICE
#
#       Full or Part-Time Salary or Hourly  Typical Hours Hourly Rate  salary
# 15387                 F           Salary            NaN         NaN     1.0

# %% [markdown]
# 12-what the mean ,max and min for Hourly Rate

# %%
data
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Hourly Rate    salary
# 0                     F           Salary            NaN         NaN  107790.0
# ...

# %%
data['Hourly Rate er']=data['Hourly Rate'].str.replace('$','').astype(float)

# %%
data.head(100)
# Out:
#                      Name                      Job Titles   Department  \
# 0        ALLISON,  PAUL W                      LIEUTENANT         FIRE
# 1         BRUNO,  KEVIN D                        SERGEANT       POLICE
# 2         COOPER,  JOHN E                  LIEUTENANT-EMT         FIRE
# 3        CRESPO,  VILMA I                      STAFF ASST          LAW
# 4        DOLAN,  ROBERT J                        SERGEANT       POLICE
# ..                    ...                             ...          ...
# 95         ABRON,  FLOYD                   POLICE OFFICER       POLICE
# 96     ABRONS,  KENNETH L             ELECTRICAL MECHANIC     AVIATION
# 97  ABUBAKER,  MOHAMMED G  SENIOR ENVIRONMENTAL INSPECTOR       HEALTH
# 98      ABUDAYEH,  ELIAS                   POLICE OFFICER       POLICE
# 99    ABUHASHISH,  AWWAD                          PLUMBER  WATER MGMNT
#
#    Full or Part-Time Salary or Hourly  Typical Hours Hourly Rate    salary  \
# ...

# %%
data
# Out:
#                         Name               Job Titles Department  \
# 0           ALLISON,  PAUL W               LIEUTENANT       FIRE
# 1            BRUNO,  KEVIN D                 SERGEANT     POLICE
# 2            COOPER,  JOHN E           LIEUTENANT-EMT       FIRE
# 3           CRESPO,  VILMA I               STAFF ASST        LAW
# 4           DOLAN,  ROBERT J                 SERGEANT     POLICE
# ...                      ...                      ...        ...
# 32653     ZYGOWICZ,  PETER J           POLICE OFFICER     POLICE
# 32654  ZYLINSKA,  KATARZYNA            POLICE OFFICER     POLICE
# 32655      ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32656    ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32657   ZYSKOWSKI,  DARIUSZ   CHIEF DATA BASE ANALYST       DoIT
#
#       Full or Part-Time Salary or Hourly  Typical Hours Hourly Rate    salary  \
# 0                     F           Salary            NaN         NaN  107790.0
# ...

# %%
data.dtypes
# Out:
# Name                  object
# Job Titles            object
# Department            object
# Full or Part-Time     object
# Salary or Hourly      object
# Typical Hours        float64
# Hourly Rate           object
# salary               float64
# Hourly Rate er       float64
# dtype: object

# %%
data['Hourly Rate er'].agg([max,min])
# Out:
# C:\Users\enaam\AppData\Local\Temp\ipykernel_14772\2847741593.py:1: FutureWarning: The provided callable <built-in function max> is currently using Series.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   data['Hourly Rate er'].agg([max,min])
# C:\Users\enaam\AppData\Local\Temp\ipykernel_14772\2847741593.py:1: FutureWarning: The provided callable <built-in function min> is currently using Series.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   data['Hourly Rate er'].agg([max,min])
# max    96.00
# min     2.65
# Name: Hourly Rate er, dtype: float64

# %% [markdown]
# 13-how many employee are earn less than the average hourly rate?

# %% [markdown]
# data.dtypes

# %%
data[data['Hourly Rate er'] < data['Hourly Rate er'].mean()].count()['Hourly Rate er']
# Out:
# 2791

# %% [markdown]
# 15-how many employee are paid hourly and they have full time job?

# %%
data[(data['Hourly Rate er'].notnull())& (data['Full or Part-Time']=='F')].count()
# Out:
# Name                 5906
# Job Titles           5906
# Department           5906
# Full or Part-Time    5906
# Salary or Hourly     5906
# Typical Hours        5906
# Hourly Rate          5906
# salary                  0
# Hourly Rate er       5906
# dtype: int64

# %% [markdown]
# 16-how many unique job titles are there in data

# %%
data['Job Titles'].nunique()
# Out:
# 1095
